# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %matplotlib inline

import warnings 
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv('used_device_data.csv')

# %%
plt.figure(figsize=(12,10))
sns.barplot(df,y='device_brand',x=df['normalized_used_price'])
plt.show();
